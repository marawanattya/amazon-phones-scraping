# %% [markdown]
# # ***scrap links***

# %%
# !pip install aiohttp backoff
# Out:
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (3.10.5)
# Collecting backoff
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (4.0.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp) (3.10)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: backoff
# Successfully installed backoff-2.2.1

# %%
import asyncio
import aiohttp
import random
import time
import pandas as pd
from bs4 import BeautifulSoup as bf
from aiohttp import ClientSession
from typing import Set, Tuple, Optional
import logging
import nest_asyncio
import asyncio

nest_asyncio.apply()

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

user_agents = [
    "Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)",
    "Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)",
    "Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)",
    "Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)",
    "Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)",
    "Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)",
    "Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)",
    "Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)",
    "Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)",
    "Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)",
    "Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)",
    "Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)",
    "Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)",
    "Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)",
    "Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)",
]

def get_random_user_agent() -> str:
    return random.choice(user_agents)

async def get_html(url: str, session: ClientSession) -> Tuple[Optional[str], Optional[str]]:
    user_agent = get_random_user_agent()
    print(f"User-Agent: {user_agent}")
    headers = {
        'User-Agent': user_agent,
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/'
    }
    try:
        async with session.get(url, headers=headers, timeout=120) as response:
            response.raise_for_status()
            html = await response.text()
            await asyncio.sleep(random.uniform(1, 2))  # Increased delay
            return html, user_agent
    except aiohttp.ClientError as e:
        logger.error(f"Request error for {url} \n User-Agent: {user_agent}: {e}")
        return None, None

page_count = 0


async def extract_job_links(html: str) -> Set[str]:
    soup = bf(html, 'html.parser')
    product_links = soup.find_all('a', attrs={'class': 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
    print(f'Found {len(product_links)} URLs -----------------------------------------------------')

    urls_set = {f'https://www.amazon.com{link.get("href")}' for link in product_links if link.get('href')}
    print(f'Found {len(urls_set)} unique URLs')
    global page_count
    page_count += 1
    print(f"Processed page {page_count}")

    return urls_set

async def scrape_page(session: ClientSession, page_num: int, max_retries: int = 6) -> Set[str]:
    url = f"https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page={page_num}&qid=1723567169&rnid=113334702011&ref=sr_pg_2"

    for attempt in range(max_retries):
        html, user_agent = await get_html(url, session)
        if html:
            urls = await extract_job_links(html)
            if urls:
                return urls
        logger.warning(f"No product links found on page {page_num}. Retrying... (Attempt {attempt + 1}/{max_retries})")
        await asyncio.sleep(random.uniform(2, 5))  # Longer delay before retrying

    logger.error(f"Failed to find product links on page {page_num} after {max_retries} attempts.")
    return set()

async def main():
    all_urls = set()
    async with aiohttp.ClientSession() as session:
        tasks = [scrape_page(session, page) for page in range(1, 190)]
        results = await asyncio.gather(*tasks)
        for urls in results:
            all_urls.update(urls)

    logger.info(f"Total URLs scraped: {len(all_urls)}")
    print(f"Total URLs scraped: {len(all_urls)}")
    return list(all_urls)


# Run the main function
urls = asyncio.get_event_loop().run_until_complete(main())

# Create and save the DataFrame
df = pd.DataFrame(urls, columns=['URL'])
df.to_csv('links.csv', index=False)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=1&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=1&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 1. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=2&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=2&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 2. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=4&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=4&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 4. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=3&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=3&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 3. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=5&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=5&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 5. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=6&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=6&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 6. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=7&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=7&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 7. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=8&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=8&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 8. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=9&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=9&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 9. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=10&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=10&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 10. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=11&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=11&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 11. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=12&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=12&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 12. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=13&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=13&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 13. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=14&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=14&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 14. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=15&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=15&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 15. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=16&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=16&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 16. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=17&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=17&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 17. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=18&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=18&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 18. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=19&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=19&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 19. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=20&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=20&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 20. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=21&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=21&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 21. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=22&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=22&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 22. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=23&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=23&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 23. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=25&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=25&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 25. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=26&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=26&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 26. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=27&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=27&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 27. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=28&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=28&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 28. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=29&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=29&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 29. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=30&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=30&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 30. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=31&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=31&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 31. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=32&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=32&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 32. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=33&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=33&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 33. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=34&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=34&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 34. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=35&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=35&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 35. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=36&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=36&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 36. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=37&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=37&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 37. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=38&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=38&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 38. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=39&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=39&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 39. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=40&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=40&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 40. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=41&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=41&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 41. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=43&qid=1723567169&rnid=113334702011&ref=sr_pg_2
#  User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots): 503, message='Service Unavailable', url='https://www.amazon.com/s?i=mobile&rh=n:7072561011,p_n_feature_thirty-nine_browse-bin:113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=43&qid=1723567169&rnid=113334702011&ref=sr_pg_2'
# WARNING:__main__:No product links found on page 43. Retrying... (Attempt 1/6)
# ERROR:__main__:Request error for https://www.amazon.com/s?i=mobile&rh=n%3A7072561011%2Cp_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&s=featured-rank&dc&fs=true&page=44&qid=1723567169&rnid=113334702011&ref=sr_pg_2
# ...
# Processed page 374
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 375
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 376
# WARNING:__main__:No product links found on page 80. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 377
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 378
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 379
# WARNING:__main__:No product links found on page 97. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 380
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 381
# Found 28 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 382
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 383
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 384
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 385
# WARNING:__main__:No product links found on page 68. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 386
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 387
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 388
# Found 26 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 389
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 390
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 391
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 392
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 393
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 394
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 395
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 396
# Found 26 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 397
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 398
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 399
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 400
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 401
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 402
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 403
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 404
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 405
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 406
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 407
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 408
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 409
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 410
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# WARNING:__main__:No product links found on page 129. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 411
# WARNING:__main__:No product links found on page 88. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 412
# WARNING:__main__:No product links found on page 28. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 413
# WARNING:__main__:No product links found on page 143. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 414
# WARNING:__main__:No product links found on page 35. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 415
# WARNING:__main__:No product links found on page 31. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 416
# WARNING:__main__:No product links found on page 113. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 417
# WARNING:__main__:No product links found on page 49. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 418
# WARNING:__main__:No product links found on page 34. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 419
# WARNING:__main__:No product links found on page 39. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 420
# WARNING:__main__:No product links found on page 125. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 421
# WARNING:__main__:No product links found on page 37. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 422
# WARNING:__main__:No product links found on page 25. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 423
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# WARNING:__main__:No product links found on page 93. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 424
# WARNING:__main__:No product links found on page 95. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 425
# WARNING:__main__:No product links found on page 84. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 426
# WARNING:__main__:No product links found on page 83. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 427
# WARNING:__main__:No product links found on page 185. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 428
# WARNING:__main__:No product links found on page 102. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 429
# WARNING:__main__:No product links found on page 106. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 430
# WARNING:__main__:No product links found on page 154. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 431
# WARNING:__main__:No product links found on page 146. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 432
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 433
# Found 26 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 434
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# WARNING:__main__:No product links found on page 114. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 435
# WARNING:__main__:No product links found on page 54. Retrying... (Attempt 2/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 436
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 437
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 438
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# WARNING:__main__:No product links found on page 16. Retrying... (Attempt 3/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 439
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 440
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 441
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 442
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 443
# Found 26 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 444
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 445
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 446
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 447
# Found 27 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 448
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 449
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 450
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 451
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 452
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 453
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 454
# WARNING:__main__:No product links found on page 18. Retrying... (Attempt 3/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 455
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 456
# Found 26 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 457
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 458
# WARNING:__main__:No product links found on page 49. Retrying... (Attempt 3/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 459
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 460
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 461
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 462
# WARNING:__main__:No product links found on page 34. Retrying... (Attempt 3/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 463
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 464
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 465
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 466
# Found 25 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 467
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# WARNING:__main__:No product links found on page 18. Retrying... (Attempt 4/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 468
# Found 26 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 469
# Found 24 -----------------------------------------------------
# Found 24 unique URLs
# Processed page 470
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# WARNING:__main__:No product links found on page 18. Retrying... (Attempt 5/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 471
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# WARNING:__main__:No product links found on page 18. Retrying... (Attempt 6/6)
# Found 0 -----------------------------------------------------
# Found 0 unique URLs
# Processed page 472
# ERROR:__main__:Failed to find product links on page 18 after 6 attempts.
# Total URLs scraped: 4483

# %%
path= '/content/links.csv'
df = pd.read_csv(path)

# %%
print(len(df))
# Out:
# 4504

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # ***scrap products***

# %%
import requests
from bs4 import BeautifulSoup
import random
import time
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import re

def scrap_page(soup):
    data = {
        'color': None, 'image_links': None, 'descriptions': None, 'kind_product': None,
        'ratings': None, 'number_of_ratings': None, 'status': None, 'number_of_buyers_last_month_more_than': None,
        'typical_price': None, 'price': None, 'you_save': None, 'discount': None,
        'brand': None, 'os': None, 'cpu_model': None, 'resolution': None, 'name': None,
        'wireless_carrier': None, 'cellular_technology': None, 'dimensions': None,
        'asin': None, 'model': None, 'amazon_renewed': None, 'renewed_smartphones': None,
        'battery_capacity': None, 'battery_power': None, 'charging_time': None,
        'ram': None, 'storage': None, 'screen_size': None, 'connectivity_technologies': None,
        'wireless_network': None, 'cpu_speed': None, 'reviews_usa': None, 'reviews_other': None
    }

    # Extract basic information
    span_selection = soup.find('span', {'class': 'selection'})
    label_text = soup.find('label', {'class': 'a-form-label'}).text.strip().lower() if soup.find('label', {'class': 'a-form-label'}) else ''
    data['color'] = span_selection.text.strip() if span_selection and label_text == 'color:' else None
    imgs = soup.find('ul', {'class': 'a-unordered-list a-nostyle a-button-list a-vertical a-spacing-top-micro regularAltImageViewLayout'})
    data['image_links'] = [img.get('src') for img in imgs.find_all('img')] if imgs else None
    des = soup.find('ul', {'class': 'a-unordered-list a-vertical a-spacing-mini'})
    data['descriptions'] = des.text.strip() if des else None
    kind = soup.find_all('span', {'class': 'a-list-item'})
    data['kind_product'] = kind[2].text.strip() if len(kind) > 2 else None

    # Extract ratings and status
    rate_div = soup.find('div', {'id': 'averageCustomerReviews'})
    if rate_div:
        data['ratings'] = rate_div.find('span', {'class': 'a-size-base a-color-base'}).text.strip() if rate_div.find('span', {'class': 'a-size-base a-color-base'}) else None
        number_rate = rate_div.find('span', {'id': 'acrCustomerReviewText'})
        data['number_of_ratings'] = number_rate.text.strip().split()[0] if number_rate else None
    data['status'] = soup.find('span', {'class': 'a-size-medium a-color-success'}).text.strip() if soup.find('span', {'class': 'a-size-medium a-color-success'}) else None
    buys = soup.find('span', {'id': 'social-proofing-faceout-title-tk_bought'})
    data['number_of_buyers_last_month_more_than'] = buys.text.strip().split()[0] if buys else None
    des = soup.find('span', attrs={'class': 'a-size-medium-plus _product-comparison-desktop_priceStyle_savings-percent__3-qzG'})
    data['discount'] = des.text.strip() if des else None
    pric = soup.find('span', attrs={'class': 'a-price-whole'})
    data['price'] = pric.text.strip() if pric else None
    tpr = soup.find('span', attrs={'class': 'a-size-mini a-color-secondary aok-nowrap a-text-strike'})
    data['typical_price'] = tpr.text.strip() if tpr else None


    # Extract product details
    for table in [soup.find('div', {'class': 'a-section a-spacing-small a-spacing-top-small'}),
                  soup.find('table', {'id': 'productDetails_detailBullets_sections1'})]:
        if table:
            for row in table.find_all('tr'):
                header = row.find('td', {'class': 'a-span3'}) or row.find('th')
                value = row.find('td', {'class': 'a-span9'}) or row.find('td')
                if header and value:
                    header_text = header.text.strip().lower()
                    value_text = value.text.strip()
                    if 'brand' in header_text: data['brand'] = value_text
                    elif 'color' in header_text and data['color']== None : data['color'] = value_text
                    elif 'operating system' in header_text: data['os'] = value_text
                    elif 'cpu model' in header_text: data['cpu_model'] = value_text
                    elif 'resolution' in header_text: data['resolution'] = value_text
                    elif 'model name' in header_text: data['name'] = value_text
                    elif 'wireless carrier' in header_text: data['wireless_carrier'] = value_text
                    elif 'cellular technology' in header_text: data['cellular_technology'] = value_text
                    elif 'dimensions' in header_text: data['dimensions'] = value_text
                    elif 'asin' in header_text: data['asin'] = value_text
                    elif 'model number' in header_text: data['model'] = value_text
                    elif 'sellers rank' in header_text:
                        numbers = re.findall(r'\d+', value_text)
                        data['amazon_renewed'] = numbers[0] if len(numbers) >= 1 else None
                        data['renewed_smartphones'] = numbers[2] if len(numbers) >= 3 else None
                    elif 'battery capacity' in header_text: data['battery_capacity'] = value_text
                    elif 'battery power' in header_text: data['battery_power'] = value_text
                    elif 'charging time' in header_text: data['charging_time'] = value_text
                    elif 'ram' in header_text: data['ram'] = value_text
                    elif 'storage' in header_text: data['storage'] = value_text
                    elif 'screen size' in header_text: data['screen_size'] = value_text
                    elif 'connectivity technologies' in header_text: data['connectivity_technologies'] = value_text
                    elif 'wireless network' in header_text: data['wireless_network'] = value_text
                    elif 'cpu speed' in header_text: data['cpu_speed'] = value_text

    # Extract reviews
    def extract_reviews(review_elements):
        reviews = []
        for review in review_elements:
            try:
                name = review.find('span', {'class': 'a-profile-name'}).text.strip()
                rate = review.find('span', {'class': 'a-icon-alt'}).text.strip().replace(' out of 5 stars', '')
                date_country = review.find('span', {'class': 'a-size-base a-color-secondary review-date'}).text.strip()
                parts = date_country.split(" on ")
                color = review.find('div', {'class': 'a-row a-spacing-mini review-data review-format-strip'}).find('span', attrs={'class': 'a-color-secondary'}).text.strip().replace(' Color:', '')
                content = review.find('div', {'class': 'a-expander-content reviewText review-text-content a-expander-partial-collapse-content'}).text.strip()
                support = review.find('span', {'class': 'a-size-base a-color-tertiary cr-vote-text'}).text.strip()
                reviews.append({
                    'name': name, 'rating': rate, 'country': parts[0].replace("Reviewed in ", "").strip(),
                    'date': parts[1].strip(), 'color': color, 'content': content, 'support': support
                })
            except AttributeError:
                continue
        return reviews if reviews else None

    data['reviews_usa'] = extract_reviews(soup.find_all('div', {'class': 'a-section review aok-relative'})[0:5])
    data['reviews_other'] = extract_reviews(soup.find_all('div', {'class': 'a-section review aok-relative cr-desktop-review-page-0'})[0:5])

    return data

user_agents = [
    "Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)",
    "Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)",
    "Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)",
    "Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)",
    "Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)",
    "Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)",
    "Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)",
    "Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)",
    "Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)",
    "Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)",
    "Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)",
    "Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)",
    "Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)",
    "Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)",
    "Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)",
    "Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)",
    "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)",
    "Mozilla/5.0 (compatible; Googlebot-News; +http://www.google.com/bot.html)",
    "Mozilla/5.0 (compatible; Googlebot-Image/1.0; +http://www.google.com/bot.html)",
    "Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)",
    "Mozilla/5.0 (compatible; Google-Site-Verification/1.0)",
    "Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)",
    "Mozilla/5.0 (Twitterbot/1.0)",
    "Mozilla/5.0 (compatible; Applebot/1.0; +http://www.apple.com/go/applebot)",
    "Mozilla/5.0 (compatible; LinkedInBot/1.0; +http://www.linkedin.com)",
    "Mozilla/5.0 (compatible; Pinterestbot/1.0; +http://www.pinterest.com/bot.html)",
    "Mozilla/5.0 (compatible; archive.org_bot/1.13; +http://www.archive.org/details/archive.org_bot)",
    "Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)",
    "Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)",
    "Mozilla/5.0 (compatible; WhatsApp/2.19.51; +http://www.whatsapp.com)",
]




def get_session():
    session = requests.Session()
    retry = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

def get_html(url, session):
    user_agent = random.choice(user_agents)
    headers = {
        'User-Agent': user_agent,
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/'
    }
    try:
        response = session.get(url, headers=headers, timeout=15)
        response.raise_for_status()
        time.sleep(random.uniform(1, 2))  # Increased delay
        return response, user_agent
    except requests.exceptions.RequestException as e:
        print(f"Request error for {url} \n User-Agent: {user_agent}: {e}")
        return None, None

def scrap(link, session):
    try:
        response, user_agent = get_html(link, session)
        print(f"User-Agent: {user_agent}")
        if response is None:
            return None, link

        soup = BeautifulSoup(response.text, 'lxml')
        product_title_element = soup.find('span', attrs={'id': 'productTitle'})

        if product_title_element:
            product_title = product_title_element.text.strip()
            print(f"(Title length: {len(product_title)})")
            return scrap_page(soup), None
        else:
            print(f"No product title found for URL: {link}")
            return None, link
    except Exception as e:
        print(f"An error occurred while scraping {link}: {e}")
        return None, link


def main():
    links_df = pd.read_csv('/content/links.csv')
    links = links_df['URL'].tolist()



    results = []
    failed_urls = []
    session = get_session()

    page_count = 0
    max_retries = 6

    def process_url(url):
        nonlocal page_count
        for attempt in range(max_retries):
            result, failed_url = scrap(url, session)
            if result:
                page_count += 1
                print(f"Processed page {page_count} ---------------------------------------------")
                return result, None
            elif attempt < max_retries - 1:
                print(f"Retrying URL (attempt {attempt + 2}/{max_retries}): {url}")
                # time.sleep(random.uniform(1, 3))  # Wait before retrying
            else:
                page_count += 1
                print(f"Processed page {page_count} (failed) ---------------------------------------------")
                return None, failed_url

    with ThreadPoolExecutor(max_workers=8) as executor:
        future_to_url = {executor.submit(process_url, url): url for url in links}
        for future in as_completed(future_to_url):
            result, failed_url = future.result()
            if result:
                results.append(result)
            if failed_url:
                failed_urls.append(failed_url)

    print("\nScraping completed.")
    print(f"Successfully scraped: {len(results)} products")
    print(f"Failed URLs: {len(failed_urls)}")

    if failed_urls:
        print("\nURLs that failed to scrape after all retries:")
        for url in failed_urls:
            print(url)

    if results:
        combined_data = {key: [] for key in results[0].keys()}
        for result in results:
            for key, value in result.items():
                combined_data[key].append(value)

        df = pd.DataFrame(combined_data)
        output_file = 'amazon_product_data.csv'
        df.to_csv(output_file, index=False)
        print(f"\nData saved to {output_file}")
    else:
        print("\nNo data was successfully scraped.")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)User-Agent: Mozilla/5.0 (compatible; Pinterestbot/1.0; +http://www.pinterest.com/bot.html)
#
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# (Title length: 69)
# (Title length: 74)
# Processed page 3199 ---------------------------------------------
# (Title length: 104)Processed page 3200 ---------------------------------------------
#
# Processed page 3201 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# (Title length: 127)
# Processed page 3202 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# Request error for https://www.amazon.com/Samsung-Galaxy-Factory-Unlock-512Gb/dp/B07GDSZ2KT/ref=sr_1_3699?dib=eyJ2IjoiMSJ9.gnNi28LuYdDoDUtZNwsU8txKQvp2AomGrXNYrlRQZ2K3mcfnP_VNQS9FGWBOy8CXu58mAofy3Rt9kVeQ_h5McYBD5z7cpI8Db0BySJ4vRhgl1YLWaA3NIpkZ3-CqriFw9eHMuKDVMVMnxt6sXpNL-jP2xYhIUIMpYTZ7w33k9FOYkUwzo_olavOtXvv9julx1MVUp-GdTeS3ixYpxUE1pxsBTB5jvWHS5iIF1wVcT8MViOqvfTzqPbA_4oKRXfEYejwjZWPASZNbUSuboHDiXrU6_9vQcxQToLg0lZ_hb08.DArHF3k5S92w7EsQ2iO-gi0IsF5ohwcy42D1C8ADldY&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3699
#  User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-Galaxy-Factory-Unlock-512Gb/dp/B07GDSZ2KT (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-Galaxy-Factory-Unlock-512Gb/dp/B07GDSZ2KT/ref=sr_1_3699?dib=eyJ2IjoiMSJ9.gnNi28LuYdDoDUtZNwsU8txKQvp2AomGrXNYrlRQZ2K3mcfnP_VNQS9FGWBOy8CXu58mAofy3Rt9kVeQ_h5McYBD5z7cpI8Db0BySJ4vRhgl1YLWaA3NIpkZ3-CqriFw9eHMuKDVMVMnxt6sXpNL-jP2xYhIUIMpYTZ7w33k9FOYkUwzo_olavOtXvv9julx1MVUp-GdTeS3ixYpxUE1pxsBTB5jvWHS5iIF1wVcT8MViOqvfTzqPbA_4oKRXfEYejwjZWPASZNbUSuboHDiXrU6_9vQcxQToLg0lZ_hb08.DArHF3k5S92w7EsQ2iO-gi0IsF5ohwcy42D1C8ADldY&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3699
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# Request error for https://www.amazon.com/Samsung-Galaxy-Factory-Unlock-512Gb/dp/B07GDSZ2KT/ref=sr_1_3699?dib=eyJ2IjoiMSJ9.gnNi28LuYdDoDUtZNwsU8txKQvp2AomGrXNYrlRQZ2K3mcfnP_VNQS9FGWBOy8CXu58mAofy3Rt9kVeQ_h5McYBD5z7cpI8Db0BySJ4vRhgl1YLWaA3NIpkZ3-CqriFw9eHMuKDVMVMnxt6sXpNL-jP2xYhIUIMpYTZ7w33k9FOYkUwzo_olavOtXvv9julx1MVUp-GdTeS3ixYpxUE1pxsBTB5jvWHS5iIF1wVcT8MViOqvfTzqPbA_4oKRXfEYejwjZWPASZNbUSuboHDiXrU6_9vQcxQToLg0lZ_hb08.DArHF3k5S92w7EsQ2iO-gi0IsF5ohwcy42D1C8ADldY&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3699
#  User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-Galaxy-Factory-Unlock-512Gb/dp/B07GDSZ2KT/ref=sr_1_3699?dib=eyJ2IjoiMSJ9.gnNi28LuYdDoDUtZNwsU8txKQvp2AomGrXNYrlRQZ2K3mcfnP_VNQS9FGWBOy8CXu58mAofy3Rt9kVeQ_h5McYBD5z7cpI8Db0BySJ4vRhgl1YLWaA3NIpkZ3-CqriFw9eHMuKDVMVMnxt6sXpNL-jP2xYhIUIMpYTZ7w33k9FOYkUwzo_olavOtXvv9julx1MVUp-GdTeS3ixYpxUE1pxsBTB5jvWHS5iIF1wVcT8MViOqvfTzqPbA_4oKRXfEYejwjZWPASZNbUSuboHDiXrU6_9vQcxQToLg0lZ_hb08.DArHF3k5S92w7EsQ2iO-gi0IsF5ohwcy42D1C8ADldY&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3699 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 3/6): https://www.amazon.com/Samsung-Galaxy-Factory-Unlock-512Gb/dp/B07GDSZ2KT/ref=sr_1_3699?dib=eyJ2IjoiMSJ9.gnNi28LuYdDoDUtZNwsU8txKQvp2AomGrXNYrlRQZ2K3mcfnP_VNQS9FGWBOy8CXu58mAofy3Rt9kVeQ_h5McYBD5z7cpI8Db0BySJ4vRhgl1YLWaA3NIpkZ3-CqriFw9eHMuKDVMVMnxt6sXpNL-jP2xYhIUIMpYTZ7w33k9FOYkUwzo_olavOtXvv9julx1MVUp-GdTeS3ixYpxUE1pxsBTB5jvWHS5iIF1wVcT8MViOqvfTzqPbA_4oKRXfEYejwjZWPASZNbUSuboHDiXrU6_9vQcxQToLg0lZ_hb08.DArHF3k5S92w7EsQ2iO-gi0IsF5ohwcy42D1C8ADldY&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3699
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# (Title length: 49)
# (Title length: 71)
# Processed page 3203 ---------------------------------------------
# Processed page 3204 ---------------------------------------------
# (Title length: 200)
# Processed page 3205 ---------------------------------------------
# Request error for https://www.amazon.com/Orbic-Wonder-Prepaid-Carrier-Locked/dp/B07FD2BGNR
#  User-Agent: Mozilla/5.0 (compatible; Googlebot-Image/1.0; +http://www.google.com/bot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Orbic-Wonder-Prepaid-Carrier-Locked/dp/B07FD2BGNR (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Orbic-Wonder-Prepaid-Carrier-Locked/dp/B07FD2BGNR
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# User-Agent: Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)
# (Title length: 171)
# Processed page 3206 ---------------------------------------------
# (Title length: 81)
# User-Agent: Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# (Title length: 58)
# Processed page 3207 ---------------------------------------------
# Processed page 3208 ---------------------------------------------
# Request error for https://www.amazon.com/Sony-Xperia-J9110-Dual-SIM-128GB/dp/B07T5SXYMQ
#  User-Agent: Mozilla/5.0 (compatible; Google-Site-Verification/1.0): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Sony-Xperia-J9110-Dual-SIM-128GB/dp/B07T5SXYMQ (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Sony-Xperia-J9110-Dual-SIM-128GB/dp/B07T5SXYMQ
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# No product title found for URL: https://www.amazon.com/Unlocked-Smartphone-Androids-4500mAh-Battery/dp/B0C3RRP8LM
# Retrying URL (attempt 2/6): https://www.amazon.com/Unlocked-Smartphone-Androids-4500mAh-Battery/dp/B0C3RRP8LM
# (Title length: 64)(Title length: 79)
#
# Processed page 3209 ---------------------------------------------
# Processed page 3210 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; LinkedInBot/1.0; +http://www.linkedin.com)
# User-Agent: Mozilla/5.0 (compatible; LinkedInBot/1.0; +http://www.linkedin.com)
# User-Agent: Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)
# (Title length: 61)
# Processed page 3211 ---------------------------------------------
# (Title length: 161)
# Processed page 3212 ---------------------------------------------
# (Title length: 73)
# Processed page 3213 ---------------------------------------------
# (Title length: 131)
# User-Agent: Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)
# Processed page 3214 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# (Title length: 198)(Title length: 84)
#
# (Title length: 64)
# Processed page 3215 ---------------------------------------------
# Processed page 3216 ---------------------------------------------
# Processed page 3217 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# (Title length: 66)
# Processed page 3218 ---------------------------------------------
# User-Agent: Mozilla/5.0 (Twitterbot/1.0)
# (Title length: 167)
# Processed page 3219 ---------------------------------------------
# (Title length: 102)
# Processed page 3220 ---------------------------------------------
# (Title length: 29)
# (Title length: 72)
# (Title length: 80)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# Processed page 3221 ---------------------------------------------
# Processed page 3222 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Googlebot-News; +http://www.google.com/bot.html)
# Processed page 3223 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Pinterestbot/1.0; +http://www.pinterest.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# (Title length: 61)
# Processed page 3224 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# (Title length: 188)
# Processed page 3225 ---------------------------------------------
# (Title length: 168)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# (Title length: 200)
# Processed page 3226 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# (Title length: 37)
# Processed page 3228 ---------------------------------------------
# Request error for https://www.amazon.com/Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1
#  User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1
# Request error for https://www.amazon.com/Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1
#  User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 3/6): https://www.amazon.com/Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1
# (Title length: 146)
# Processed page 3229 ---------------------------------------------
# Request error for https://www.amazon.com/Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1
#  User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 4/6): https://www.amazon.com/Yemjaw-A15-Smartphone-Fingerprint-Titanium/dp/B0DCZTS5L1
# Request error for https://www.amazon.com/ZTE-Maven-Phone-Annual-Contract/dp/B010Y2KABC/ref=sr_1_3208?dib=eyJ2IjoiMSJ9.v4h0yHaoywOcVc2qDKwDjNbTMcfFcayYgvL7gvhjfetdsQbQr7GobNsz4Ks9MQWwcz5lwBaXd5fpGhMmZtkQqvMSMp0XKDyc2W6zwCixoNn-n301YgkEdBHC40HDYbSlYN6kEwqp65SO7FXpKeQb8JgvxMcXfWA5ZtrLAVP-bE-Lr-E0vPYfRKNTOyttRMjxm7f7r03sAgHRDmjGoMq0j63oD2ZcyVbyeoL4vLFF2gC6ar81YOwU733QfbIMKyzr9HM2guPHGneVOB71prTDz-omjeMuFS9DZGsK0rgqlrk.V6oM4JzyW7H9i2LeQQPOYE8F4qnq3sNAiCC2SpzzaK4&dib_tag=se&qid=1726930565&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3208
#  User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /ZTE-Maven-Phone-Annual-Contract/dp/B010Y2KABC/ref=sr_1_3208?dib=eyJ2IjoiMSJ9.v4h0yHaoywOcVc2qDKwDjNbTMcfFcayYgvL7gvhjfetdsQbQr7GobNsz4Ks9MQWwcz5lwBaXd5fpGhMmZtkQqvMSMp0XKDyc2W6zwCixoNn-n301YgkEdBHC40HDYbSlYN6kEwqp65SO7FXpKeQb8JgvxMcXfWA5ZtrLAVP-bE-Lr-E0vPYfRKNTOyttRMjxm7f7r03sAgHRDmjGoMq0j63oD2ZcyVbyeoL4vLFF2gC6ar81YOwU733QfbIMKyzr9HM2guPHGneVOB71prTDz-omjeMuFS9DZGsK0rgqlrk.V6oM4JzyW7H9i2LeQQPOYE8F4qnq3sNAiCC2SpzzaK4&dib_tag=se&qid=1726930565&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3208 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/ZTE-Maven-Phone-Annual-Contract/dp/B010Y2KABC/ref=sr_1_3208?dib=eyJ2IjoiMSJ9.v4h0yHaoywOcVc2qDKwDjNbTMcfFcayYgvL7gvhjfetdsQbQr7GobNsz4Ks9MQWwcz5lwBaXd5fpGhMmZtkQqvMSMp0XKDyc2W6zwCixoNn-n301YgkEdBHC40HDYbSlYN6kEwqp65SO7FXpKeQb8JgvxMcXfWA5ZtrLAVP-bE-Lr-E0vPYfRKNTOyttRMjxm7f7r03sAgHRDmjGoMq0j63oD2ZcyVbyeoL4vLFF2gC6ar81YOwU733QfbIMKyzr9HM2guPHGneVOB71prTDz-omjeMuFS9DZGsK0rgqlrk.V6oM4JzyW7H9i2LeQQPOYE8F4qnq3sNAiCC2SpzzaK4&dib_tag=se&qid=1726930565&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3208
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# Request error for https://www.amazon.com/ZTE-Maven-Phone-Annual-Contract/dp/B010Y2KABC/ref=sr_1_3208?dib=eyJ2IjoiMSJ9.v4h0yHaoywOcVc2qDKwDjNbTMcfFcayYgvL7gvhjfetdsQbQr7GobNsz4Ks9MQWwcz5lwBaXd5fpGhMmZtkQqvMSMp0XKDyc2W6zwCixoNn-n301YgkEdBHC40HDYbSlYN6kEwqp65SO7FXpKeQb8JgvxMcXfWA5ZtrLAVP-bE-Lr-E0vPYfRKNTOyttRMjxm7f7r03sAgHRDmjGoMq0j63oD2ZcyVbyeoL4vLFF2gC6ar81YOwU733QfbIMKyzr9HM2guPHGneVOB71prTDz-omjeMuFS9DZGsK0rgqlrk.V6oM4JzyW7H9i2LeQQPOYE8F4qnq3sNAiCC2SpzzaK4&dib_tag=se&qid=1726930565&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3208
#  User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /ZTE-Maven-Phone-Annual-Contract/dp/B010Y2KABC/ref=sr_1_3208?dib=eyJ2IjoiMSJ9.v4h0yHaoywOcVc2qDKwDjNbTMcfFcayYgvL7gvhjfetdsQbQr7GobNsz4Ks9MQWwcz5lwBaXd5fpGhMmZtkQqvMSMp0XKDyc2W6zwCixoNn-n301YgkEdBHC40HDYbSlYN6kEwqp65SO7FXpKeQb8JgvxMcXfWA5ZtrLAVP-bE-Lr-E0vPYfRKNTOyttRMjxm7f7r03sAgHRDmjGoMq0j63oD2ZcyVbyeoL4vLFF2gC6ar81YOwU733QfbIMKyzr9HM2guPHGneVOB71prTDz-omjeMuFS9DZGsK0rgqlrk.V6oM4JzyW7H9i2LeQQPOYE8F4qnq3sNAiCC2SpzzaK4&dib_tag=se&qid=1726930565&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3208 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 3/6): https://www.amazon.com/ZTE-Maven-Phone-Annual-Contract/dp/B010Y2KABC/ref=sr_1_3208?dib=eyJ2IjoiMSJ9.v4h0yHaoywOcVc2qDKwDjNbTMcfFcayYgvL7gvhjfetdsQbQr7GobNsz4Ks9MQWwcz5lwBaXd5fpGhMmZtkQqvMSMp0XKDyc2W6zwCixoNn-n301YgkEdBHC40HDYbSlYN6kEwqp65SO7FXpKeQb8JgvxMcXfWA5ZtrLAVP-bE-Lr-E0vPYfRKNTOyttRMjxm7f7r03sAgHRDmjGoMq0j63oD2ZcyVbyeoL4vLFF2gC6ar81YOwU733QfbIMKyzr9HM2guPHGneVOB71prTDz-omjeMuFS9DZGsK0rgqlrk.V6oM4JzyW7H9i2LeQQPOYE8F4qnq3sNAiCC2SpzzaK4&dib_tag=se&qid=1726930565&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3208
# User-Agent: Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)
# (Title length: 176)
# (Title length: 44)
# Processed page 3230 ---------------------------------------------
# Processed page 3231 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# Request error for https://www.amazon.com/Sony-Xperia-XQ-DQ72-256GB-Unlocked/dp/B0C584DBX6
#  User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Sony-Xperia-XQ-DQ72-256GB-Unlocked/dp/B0C584DBX6 (Caused by ResponseError('too many 503 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Sony-Xperia-XQ-DQ72-256GB-Unlocked/dp/B0C584DBX6
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# (Title length: 129)
# (Title length: 120)
# Processed page 3232 ---------------------------------------------Processed page 3233 ---------------------------------------------
#
# User-Agent: Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)
# Request error for https://www.amazon.com/LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q
#  User-Agent: Mozilla/5.0 (compatible; Applebot/1.0; +http://www.apple.com/go/applebot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q
# Request error for https://www.amazon.com/LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q
#  User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 3/6): https://www.amazon.com/LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q
# (Title length: 141)
# (Title length: 159)
# (Title length: 31)
# Processed page 3234 ---------------------------------------------
# (Title length: 47)
# Processed page 3235 ---------------------------------------------Processed page 3236 ---------------------------------------------
#
# Processed page 3237 ---------------------------------------------
# Request error for https://www.amazon.com/LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q
#  User-Agent: Mozilla/5.0 (compatible; archive.org_bot/1.13; +http://www.archive.org/details/archive.org_bot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 4/6): https://www.amazon.com/LG-LG-H791-Factory-Unlocked-Smartphone/dp/B016B7IN8Q
# Request error for https://www.amazon.com/Google-Unlocked-Android-12-2MP-Camera/dp/B07HKPN611
#  User-Agent: Mozilla/5.0 (compatible; Google-Site-Verification/1.0): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Google-Unlocked-Android-12-2MP-Camera/dp/B07HKPN611 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Google-Unlocked-Android-12-2MP-Camera/dp/B07HKPN611
# User-Agent: Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (Twitterbot/1.0)
# User-Agent: Mozilla/5.0 (Twitterbot/1.0)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# (Title length: 64)
# (Title length: 128)
# Processed page 3238 ---------------------------------------------
# Processed page 3239 ---------------------------------------------
# (Title length: 164)
# Processed page 3240 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Applebot/1.0; +http://www.apple.com/go/applebot)
# User-Agent: Mozilla/5.0 (compatible; Googlebot-News; +http://www.google.com/bot.html)
# Request error for https://www.amazon.com/H872-T-Mobile-Carrier-Android-Phone/dp/B07WG9TNMW/ref=sr_1_2736?dib=eyJ2IjoiMSJ9.kZpbMmh4S6pWHbvLUs4idsz6Hg6Wa-wI_8g16OYwEY1bBGmRt1lljjkuGZl9CEcGsKLD41XuU1ctPLAo9eeLiqJvdOJwP8UkpctFa0y0Rf_5zPPtP9t3NNVZdmXbcJ3VmGAs6vBfj2gO73pMeo74xZssZfHGbfl7s4CUhYgRMXcc8eFO8gteue9VnvLF4LRoTCdsjtrxp82DiKe-6MmBkvVsE5Q4t2JzcbTHg47j-bWAXAaL1PwVi8N8MRzSx4zdUEBlDZ2R60Aou7zx-Yh_7LO2BX1Cb0Wwj0M4mE2IJS8.SaPIZVS57q_lgczgz4c4OsgTYWiKlc4rcFjslKeOa_c&dib_tag=se&qid=1726930569&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2736
#  User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /H872-T-Mobile-Carrier-Android-Phone/dp/B07WG9TNMW/ref=sr_1_2736?dib=eyJ2IjoiMSJ9.kZpbMmh4S6pWHbvLUs4idsz6Hg6Wa-wI_8g16OYwEY1bBGmRt1lljjkuGZl9CEcGsKLD41XuU1ctPLAo9eeLiqJvdOJwP8UkpctFa0y0Rf_5zPPtP9t3NNVZdmXbcJ3VmGAs6vBfj2gO73pMeo74xZssZfHGbfl7s4CUhYgRMXcc8eFO8gteue9VnvLF4LRoTCdsjtrxp82DiKe-6MmBkvVsE5Q4t2JzcbTHg47j-bWAXAaL1PwVi8N8MRzSx4zdUEBlDZ2R60Aou7zx-Yh_7LO2BX1Cb0Wwj0M4mE2IJS8.SaPIZVS57q_lgczgz4c4OsgTYWiKlc4rcFjslKeOa_c&dib_tag=se&qid=1726930569&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2736 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/H872-T-Mobile-Carrier-Android-Phone/dp/B07WG9TNMW/ref=sr_1_2736?dib=eyJ2IjoiMSJ9.kZpbMmh4S6pWHbvLUs4idsz6Hg6Wa-wI_8g16OYwEY1bBGmRt1lljjkuGZl9CEcGsKLD41XuU1ctPLAo9eeLiqJvdOJwP8UkpctFa0y0Rf_5zPPtP9t3NNVZdmXbcJ3VmGAs6vBfj2gO73pMeo74xZssZfHGbfl7s4CUhYgRMXcc8eFO8gteue9VnvLF4LRoTCdsjtrxp82DiKe-6MmBkvVsE5Q4t2JzcbTHg47j-bWAXAaL1PwVi8N8MRzSx4zdUEBlDZ2R60Aou7zx-Yh_7LO2BX1Cb0Wwj0M4mE2IJS8.SaPIZVS57q_lgczgz4c4OsgTYWiKlc4rcFjslKeOa_c&dib_tag=se&qid=1726930569&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2736
# (Title length: 166)
# (Title length: 107)
# Processed page 3241 ---------------------------------------------
# Processed page 3242 ---------------------------------------------
# (Title length: 181)
# User-Agent: Mozilla/5.0 (compatible; WhatsApp/2.19.51; +http://www.whatsapp.com)
# User-Agent: Mozilla/5.0 (Twitterbot/1.0)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# (Title length: 162)
# Processed page 3243 ---------------------------------------------
# Processed page 3244 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# (Title length: 61)
# Processed page 3245 ---------------------------------------------
# (Title length: 58)
# Processed page 3246 ---------------------------------------------
# (Title length: 200)
# (Title length: 137)
# (Title length: 175)
# (Title length: 61)
# Processed page 3247 ---------------------------------------------
# (Title length: 55)
# (Title length: 175)Processed page 3248 ---------------------------------------------
#
# User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)
# Processed page 3249 ---------------------------------------------
# Processed page 3250 ---------------------------------------------
# Processed page 3251 ---------------------------------------------
# Processed page 3252 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; LinkedInBot/1.0; +http://www.linkedin.com)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)
# Request error for https://www.amazon.com/Motorola-Dual-Sim-Factory-Unlocked-Smartphone/dp/B0B8DNP6BB
#  User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Motorola-Dual-Sim-Factory-Unlocked-Smartphone/dp/B0B8DNP6BB (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Motorola-Dual-Sim-Factory-Unlocked-Smartphone/dp/B0B8DNP6BB
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# (Title length: 140)
# (Title length: 67)
# (Title length: 65)
# (Title length: 196)
# (Title length: 141)
# Processed page 3253 ---------------------------------------------
# Processed page 3254 ---------------------------------------------Processed page 3255 ---------------------------------------------
#
# Processed page 3256 ---------------------------------------------
# Processed page 3257 ---------------------------------------------
# (Title length: 87)
# Processed page 3258 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; archive.org_bot/1.13; +http://www.archive.org/details/archive.org_bot)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# (Title length: 72)
# Processed page 3259 ---------------------------------------------
# (Title length: 178)
# (Title length: 191)
# Processed page 3260 ---------------------------------------------
# Processed page 3261 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# (Title length: 67)
# Processed page 3262 ---------------------------------------------
# (Title length: 194)
# Processed page 3263 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# (Title length: 168)
# Processed page 3264 ---------------------------------------------
# Request error for https://www.amazon.com/Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278
#  User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278
# (Title length: 132)
# Processed page 3265 ---------------------------------------------
# Request error for https://www.amazon.com/Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278
#  User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 3/6): https://www.amazon.com/Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278
# User-Agent: Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# No product title found for URL: https://www.amazon.com/Motorola-Snapdragon-Unlocked-XT2201-3-Wireless/dp/B0CV9JTPQD
# Retrying URL (attempt 2/6): https://www.amazon.com/Motorola-Snapdragon-Unlocked-XT2201-3-Wireless/dp/B0CV9JTPQD
# Request error for https://www.amazon.com/Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278
#  User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 4/6): https://www.amazon.com/Samsung-SM-G975F-Dual-SIM-Unlocked-Smartphone/dp/B07NWKP41X/ref=sr_1_2278?dib=eyJ2IjoiMSJ9.mMx4xCNtl5RKEy1S3oaSyAJQ-Fcde3FDIrAYDfBXUAalktOQ-8C5RaFu6Bu3J_fl6nwSemmAFlP5oOCUIddPNv60FqPz6Y-VAQudqJ-7c-_P6EVR2HhDh-VxWX_uUVe15KV9cktN10qUujVrx-EtbqwHdmXuGtvmR6Qc_Cx9xyNb-I_WeH5NcxkbEL-znEl-rQdiX44QcKk1qFvS6kPjzvqNtb5m9EvxISZgASYdxJnLzQn-u3xJX9k6CgkEUuVFi15W0sp94PHVE01mrbcyNPv2bYtILMOjybb6608-CLo.E0zTQUT7sjv5rvjEV2pfqJFZ-Dc4y54jjRBZ7kUgFR0&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-2278
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; Google-Site-Verification/1.0)
# (Title length: 199)
# Processed page 3266 ---------------------------------------------
# (Title length: 195)
# Request error for https://www.amazon.com/DOOGEE-S41-Plus-Waterproof-Smartphone/dp/B0D73Q5FHG
#  User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /DOOGEE-S41-Plus-Waterproof-Smartphone/dp/B0D73Q5FHG (Caused by ResponseError('too many 503 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/DOOGEE-S41-Plus-Waterproof-Smartphone/dp/B0D73Q5FHG
# Processed page 3267 ---------------------------------------------
# Request error for https://www.amazon.com/Blackview-BV4800-Smartphone-Waterproof-Fingerprint/dp/B0D1JWTYVW
#  User-Agent: Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Blackview-BV4800-Smartphone-Waterproof-Fingerprint/dp/B0D1JWTYVW (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Blackview-BV4800-Smartphone-Waterproof-Fingerprint/dp/B0D1JWTYVW
# User-Agent: Mozilla/5.0 (compatible; archive.org_bot/1.13; +http://www.archive.org/details/archive.org_bot)
# (Title length: 175)
# Processed page 3268 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (Twitterbot/1.0)
# (Title length: 124)
# Processed page 3269 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# (Title length: 197)
# (Title length: 56)
# Processed page 3270 ---------------------------------------------
# Processed page 3271 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; WhatsApp/2.19.51; +http://www.whatsapp.com)
# (Title length: 95)(Title length: 132)
#
# Processed page 3272 ---------------------------------------------Processed page 3273 ---------------------------------------------
#
# User-Agent: Mozilla/5.0 (compatible; Pinterestbot/1.0; +http://www.pinterest.com/bot.html)
# User-Agent: Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# (Title length: 188)
# (Title length: 157)
# Processed page 3274 ---------------------------------------------
# Processed page 3275 ---------------------------------------------
# (Title length: 185)
# User-Agent: Mozilla/5.0 (compatible; Googlebot-News; +http://www.google.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# Processed page 3276 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# No product title found for URL: https://www.amazon.com/Samsung-Galaxy-64GB-Unlocked-Phone/dp/B06XZRMD1J
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-Galaxy-64GB-Unlocked-Phone/dp/B06XZRMD1J
# (Title length: 78)
# Processed page 3277 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# (Title length: 93)
# (Title length: 75)
# Processed page 3278 ---------------------------------------------
# Processed page 3279 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# (Title length: 184)
# (Title length: 77)
# Processed page 3280 ---------------------------------------------
# Processed page 3281 ---------------------------------------------
# Request error for https://www.amazon.com/XT2129-2-International-Warranty-Unlocked-T-Mobile/dp/B09777J8L3
#  User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /XT2129-2-International-Warranty-Unlocked-T-Mobile/dp/B09777J8L3 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/XT2129-2-International-Warranty-Unlocked-T-Mobile/dp/B09777J8L3
# User-Agent: Mozilla/5.0 (compatible; Googlebot-Image/1.0; +http://www.google.com/bot.html)
# (Title length: 96)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# (Title length: 194)
# Processed page 3282 ---------------------------------------------
# (Title length: 142)
# (Title length: 66)
# Processed page 3283 ---------------------------------------------
# Processed page 3284 ---------------------------------------------
# Processed page 3285 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# (Title length: 173)
# Request error for https://www.amazon.com/Samsung-Galaxy-S3-Verizon-Wireless/dp/B008HTJLF6
#  User-Agent: Mozilla/5.0 (compatible; Googlebot-Image/1.0; +http://www.google.com/bot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-Galaxy-S3-Verizon-Wireless/dp/B008HTJLF6 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-Galaxy-S3-Verizon-Wireless/dp/B008HTJLF6
# Processed page 3286 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; YandexVideo/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; WhatsApp/2.19.51; +http://www.whatsapp.com)
# User-Agent: Mozilla/5.0 (compatible; Googlebot-News; +http://www.google.com/bot.html)
# (Title length: 156)
# Processed page 3287 ---------------------------------------------
# (Title length: 47)
# Processed page 3288 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Exabot/3.0; +http://www.exabot.com/go/robot)
# User-Agent: Mozilla/5.0 (compatible; YandexSearch/5.0; +http://yandex.com/bots)
# (Title length: 170)
# (Title length: 113)
# Processed page 3289 ---------------------------------------------
# Processed page 3290 ---------------------------------------------
# (Title length: 189)
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# Processed page 3291 ---------------------------------------------
# User-Agent: Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; DotBot/1.0; +http://www.opensiteexplorer.org/dotbot)
# (Title length: 123)
# No product title found for URL: https://www.amazon.com/Samsung-Galaxy-Note-Edge-Smartphone/dp/B00QL8R8Q4
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-Galaxy-Note-Edge-Smartphone/dp/B00QL8R8Q4
# Processed page 3292 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# (Title length: 104)
# Processed page 3293 ---------------------------------------------
# (Title length: 68)
# Processed page 3294 ---------------------------------------------
# (Title length: 192)
# User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# Processed page 3295 ---------------------------------------------
# (Title length: 36)
# Processed page 3296 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)Request error for https://www.amazon.com/Google-Pixel-Pro-Smartphone-Telephoto/dp/B0BKDTVR8B
#  User-Agent: Mozilla/5.0 (compatible; Applebot/1.0; +http://www.apple.com/go/applebot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Google-Pixel-Pro-Smartphone-Telephoto/dp/B0BKDTVR8B (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Google-Pixel-Pro-Smartphone-Telephoto/dp/B0BKDTVR8B
#
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# (Title length: 37)
# (Title length: 177)
# Processed page 3297 ---------------------------------------------
# Processed page 3298 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Sogou web spider/4.0; +http://www.sogou.com/docs/help/webmasters.htm#07)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# (Title length: 41)
# (Title length: 133)
# (Title length: 71)
# (Title length: 199)
# Processed page 3299 ---------------------------------------------Processed page 3300 ---------------------------------------------
#
# Processed page 3301 ---------------------------------------------
# Processed page 3302 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# (Title length: 108)
# Request error for https://www.amazon.com/Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP
#  User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.4.12; http://www.majestic12.co.uk/bot.php): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP
# Processed page 3303 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# Request error for https://www.amazon.com/Zyyini-Unlocked-6-1inch-Smartphone-Recognition/dp/B0B2KKV6DF
#  User-Agent: Mozilla/5.0 (compatible; Google-Site-Verification/1.0): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Zyyini-Unlocked-6-1inch-Smartphone-Recognition/dp/B0B2KKV6DF (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Zyyini-Unlocked-6-1inch-Smartphone-Recognition/dp/B0B2KKV6DF
# Request error for https://www.amazon.com/Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP
#  User-Agent: Mozilla/5.0 (compatible; Googlebot-Image/1.0; +http://www.google.com/bot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 3/6): https://www.amazon.com/Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# (Title length: 64)
# Request error for https://www.amazon.com/Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP
#  User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 4/6): https://www.amazon.com/Cellphone-Elderly-18000mAh-Battery-Android/dp/B0CL93T5RP
# (Title length: 122)
# (Title length: 35)
# (Title length: 171)Processed page 3304 ---------------------------------------------
#
# Processed page 3305 ---------------------------------------------Processed page 3306 ---------------------------------------------
#
# Processed page 3307 ---------------------------------------------
# No product title found for URL: https://www.amazon.com/MMY-I14-Unlocked-Smartphone-Fingerprint/dp/B0CX99CLTD
# Retrying URL (attempt 2/6): https://www.amazon.com/MMY-I14-Unlocked-Smartphone-Fingerprint/dp/B0CX99CLTD
# ...
# (Title length: 184)
# (Title length: 179)
# (Title length: 68)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# Processed page 4460 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)
# User-Agent: Mozilla/5.0 (compatible; archive.org_bot/1.13; +http://www.archive.org/details/archive.org_bot)
# Processed page 4461 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# Processed page 4462 ---------------------------------------------
# (Title length: 51)
# Processed page 4463 ---------------------------------------------
# (Title length: 100)
# Processed page 4464 ---------------------------------------------
# (Title length: 78)
# Processed page 4465 ---------------------------------------------
# (Title length: 164)
# Processed page 4466 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)
# (Title length: 181)
# Processed page 4467 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# (Title length: 69)
# Processed page 4468 ---------------------------------------------
# Request error for https://www.amazon.com/SAMSUNG-Storage-Foldable-Unlocked-compatible/dp/B0CCYRDKK9
#  User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /SAMSUNG-Storage-Foldable-Unlocked-compatible/dp/B0CCYRDKK9 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/SAMSUNG-Storage-Foldable-Unlocked-compatible/dp/B0CCYRDKK9
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# (Title length: 69)
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# Processed page 4469 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; LinkedInBot/1.0; +http://www.linkedin.com)
# Request error for https://www.amazon.com/Samsung-Galaxy-Verizon-Unlocked-128GB/dp/B07NY3CTMK
#  User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-Galaxy-Verizon-Unlocked-128GB/dp/B07NY3CTMK (Caused by ResponseError('too many 503 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-Galaxy-Verizon-Unlocked-128GB/dp/B07NY3CTMK
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# Request error for https://www.amazon.com/Samsung-Galaxy-A716U-Renewed-Unlocked/dp/B08S93R9DD/ref=sr_1_1130?dib=eyJ2IjoiMSJ9.bNQId7wcDDLLKdWiDuGXEagVyvgaJTD1t6Cn5hYQ58eqAygAQOf3zl8my1YyYAt7oFvJGZnwH7GpwtFABTinnIHCSilbLFKM9y6CHwzojKSX49oRhq1x9vHEd_2_-J67Zvs2W9PRvZYN27fN6uO99tFtURIQPZLvttkhH2MNmPDDYULYLc74Wk9DY_iA_7QeNqlSW1RzG9CFcDGGIbZNxTMQ3Ax2o-WCw7uL-B3Tc_MoR3Lqq45L-9lWzEQHcpdxNksxhXlLDGVNMB5YAnRBtdIb5uZhwTWgMj88kxoMdic.M-5tV-8VpSuOx8Ky56x0fmmWhryHYp1rVxh109oWa-U&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-1130
#  User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Samsung-Galaxy-A716U-Renewed-Unlocked/dp/B08S93R9DD/ref=sr_1_1130?dib=eyJ2IjoiMSJ9.bNQId7wcDDLLKdWiDuGXEagVyvgaJTD1t6Cn5hYQ58eqAygAQOf3zl8my1YyYAt7oFvJGZnwH7GpwtFABTinnIHCSilbLFKM9y6CHwzojKSX49oRhq1x9vHEd_2_-J67Zvs2W9PRvZYN27fN6uO99tFtURIQPZLvttkhH2MNmPDDYULYLc74Wk9DY_iA_7QeNqlSW1RzG9CFcDGGIbZNxTMQ3Ax2o-WCw7uL-B3Tc_MoR3Lqq45L-9lWzEQHcpdxNksxhXlLDGVNMB5YAnRBtdIb5uZhwTWgMj88kxoMdic.M-5tV-8VpSuOx8Ky56x0fmmWhryHYp1rVxh109oWa-U&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-1130 (Caused by ResponseError('too many 503 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-Galaxy-A716U-Renewed-Unlocked/dp/B08S93R9DD/ref=sr_1_1130?dib=eyJ2IjoiMSJ9.bNQId7wcDDLLKdWiDuGXEagVyvgaJTD1t6Cn5hYQ58eqAygAQOf3zl8my1YyYAt7oFvJGZnwH7GpwtFABTinnIHCSilbLFKM9y6CHwzojKSX49oRhq1x9vHEd_2_-J67Zvs2W9PRvZYN27fN6uO99tFtURIQPZLvttkhH2MNmPDDYULYLc74Wk9DY_iA_7QeNqlSW1RzG9CFcDGGIbZNxTMQ3Ax2o-WCw7uL-B3Tc_MoR3Lqq45L-9lWzEQHcpdxNksxhXlLDGVNMB5YAnRBtdIb5uZhwTWgMj88kxoMdic.M-5tV-8VpSuOx8Ky56x0fmmWhryHYp1rVxh109oWa-U&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-1130
# Request error for https://www.amazon.com/SAMSUNG-Storage-Foldable-Unlocked-compatible/dp/B0CCYRDKK9
#  User-Agent: Mozilla/5.0 (compatible; Google-Site-Verification/1.0): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /SAMSUNG-Storage-Foldable-Unlocked-compatible/dp/B0CCYRDKK9 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 3/6): https://www.amazon.com/SAMSUNG-Storage-Foldable-Unlocked-compatible/dp/B0CCYRDKK9
# (Title length: 65)
# (Title length: 159)
# Processed page 4470 ---------------------------------------------
# (Title length: 190)
# Processed page 4471 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# Processed page 4472 ---------------------------------------------
# (Title length: 74)
# Processed page 4473 ---------------------------------------------
# (Title length: 57)
# User-Agent: Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# Processed page 4474 ---------------------------------------------
# No product title found for URL: https://www.amazon.com/Samsung-SM-A015M-Display-Unlocked-International/dp/B08BLQWP9V
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-SM-A015M-Display-Unlocked-International/dp/B08BLQWP9V
# User-Agent: Mozilla/5.0 (compatible; SeznamBot/3.2; +http://napoveda.seznam.cz/cz/seznambot-intro/)
# User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# (Title length: 164)
# Processed page 4475 ---------------------------------------------
# User-Agent: Mozilla/5.0 (Twitterbot/1.0)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; WhatsApp/2.19.51; +http://www.whatsapp.com)
# Request error for https://www.amazon.com/Generic-Unlocked-Clearance-Android-Smartphones/dp/B0D678DC1Z
#  User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Generic-Unlocked-Clearance-Android-Smartphones/dp/B0D678DC1Z (Caused by ResponseError('too many 503 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Generic-Unlocked-Clearance-Android-Smartphones/dp/B0D678DC1Z
# User-Agent: Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)
# User-Agent: Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# (Title length: 75)
# Processed page 4476 ---------------------------------------------
# (Title length: 75)
# (Title length: 104)
# (Title length: 52)
# (Title length: 149)
# User-Agent: Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)
# Processed page 4477 ---------------------------------------------
# (Title length: 188)
# (Title length: 45)
# Processed page 4478 ---------------------------------------------
# Processed page 4479 ---------------------------------------------
# Processed page 4480 ---------------------------------------------
# Processed page 4481 ---------------------------------------------
# Processed page 4482 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# User-Agent: Mozilla/5.0 (compatible; Applebot/1.0; +http://www.apple.com/go/applebot)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; YandexBot/3.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; SemrushBot/7~bl; +http://www.semrush.com/bot)
# (Title length: 45)
# (Title length: 67)
# (Title length: 156)
# (Title length: 122)
# Processed page 4483 ---------------------------------------------
# Processed page 4484 ---------------------------------------------
# Processed page 4485 ---------------------------------------------
# Processed page 4486 ---------------------------------------------
# (Title length: 139)
# Processed page 4487 ---------------------------------------------
# (Title length: 187)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# Processed page 4488 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)
# User-Agent: Mozilla/5.0 (compatible; Slackbot-LinkExpanding 1.0; +https://api.slack.com/robots)
# User-Agent: Mozilla/5.0 (compatible; YandexImages/5.0; +http://yandex.com/bots)
# User-Agent: Mozilla/5.0 (compatible; LinkedInBot/1.0; +http://www.linkedin.com)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# (Title length: 82)
# (Title length: 42)
# (Title length: 151)
# (Title length: 57)
# (Title length: 86)
# Processed page 4489 ---------------------------------------------
# Processed page 4490 ---------------------------------------------
# Processed page 4491 ---------------------------------------------
# Processed page 4492 ---------------------------------------------
# Processed page 4493 ---------------------------------------------
# (Title length: 87)
# Processed page 4494 ---------------------------------------------
# (Title length: 87)
# Processed page 4495 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; MJ12bot/v1.2.4; http://www.majestic12.co.uk/bot.php)
# User-Agent: Mozilla/5.0 (compatible; DuckDuckBot/1.0; +http://duckduckgo.com/duckduckbot.html)
# User-Agent: Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; Googlebot-News; +http://www.google.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; PetalBot/1.0; +https://aspiegel.com/petalbot)
# User-Agent: Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
# User-Agent: Mozilla/5.0 (compatible; BLEXBot/1.0; +http://webmeup.com/crawler.html)
# (Title length: 183)
# (Title length: 54)(Title length: 115)
#
# (Title length: 180)
# (Title length: 175)
# No product title found for URL: https://www.amazon.com/Samsung-Galaxy-A13-5G-Unlocked/dp/B0B43W6V9P
# Retrying URL (attempt 2/6): https://www.amazon.com/Samsung-Galaxy-A13-5G-Unlocked/dp/B0B43W6V9P
# Processed page 4496 ---------------------------------------------
# Processed page 4497 ---------------------------------------------
# Processed page 4498 ---------------------------------------------
# Processed page 4499 ---------------------------------------------
# Processed page 4500 ---------------------------------------------
# (Title length: 170)
# Processed page 4501 ---------------------------------------------
# (Title length: 200)
# Processed page 4502 ---------------------------------------------
# User-Agent: Mozilla/5.0 (compatible; FacebookExternalHit/1.1; +http://www.facebook.com/externalhit_uatext.php)
# (Title length: 135)
# Processed page 4503 ---------------------------------------------
# Request error for https://www.amazon.com/Sony-Xperia-F3113-Android-Phone/dp/B01FJT7EE6
#  User-Agent: Mozilla/5.0 (compatible; Googlebot-Image/1.0; +http://www.google.com/bot.html): HTTPSConnectionPool(host='www.amazon.com', port=443): Max retries exceeded with url: /Sony-Xperia-F3113-Android-Phone/dp/B01FJT7EE6 (Caused by ResponseError('too many 500 error responses'))
# User-Agent: None
# Retrying URL (attempt 2/6): https://www.amazon.com/Sony-Xperia-F3113-Android-Phone/dp/B01FJT7EE6
# User-Agent: Mozilla/5.0 (compatible; CCBot/2.0; +http://commoncrawl.org/faq/)
# (Title length: 59)
# Processed page 4504 ---------------------------------------------
#
# Scraping completed.
# Successfully scraped: 4499 products
# Failed URLs: 5
#
# URLs that failed to scrape after all retries:
# https://www.amazon.com/Unlocked-Smartphones-Android-Standby-1500mAh/dp/B08YZ6BNPX/ref=sr_1_4029?dib=eyJ2IjoiMSJ9.1_VnsPQ2mmuSy6glqgxXUpOCaW93y4tmmf1SSz__loW5TVclNglIcXw550pDbWkfR_pMkjeVmAF7321214O8re_5dvhTgooVKQX7bwhFt_z78lywESHQRiONxeezyMge-QAARWkfQg17c1YMt-mMPBmEM_Tf2d40R5BZh6_z3BeiIB1zyTcwVafu5WpVV_pz71MrMiPgJkSSeRImwH-k6_NRo6AAM-4EQRGXaSuVhNTouJRpTwAtfWSDLiOo26POJ89E_xmkzAEc7voWOOQanu62tJqVGE2paiFvqswGx5k.tyN-Szbb7TSpfxojlapBpxDjQ6pKOK7MPjJBRy7krKw&dib_tag=se&qid=1726930569&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-4029
# https://www.amazon.com/Samsung-Galaxy-SM-F731U1-Factory-Unlocked/dp/B0CLF2GBGM/ref=sr_1_1113?dib=eyJ2IjoiMSJ9.bNQId7wcDDLLKdWiDuGXEagVyvgaJTD1t6Cn5hYQ58eqAygAQOf3zl8my1YyYAt7oFvJGZnwH7GpwtFABTinnIHCSilbLFKM9y6CHwzojKSX49oRhq1x9vHEd_2_-J67Zvs2W9PRvZYN27fN6uO99tFtURIQPZLvttkhH2MNmPDDYULYLc74Wk9DY_iA_7QeNqlSW1RzG9CFcDGGIbZNxTMQ3Ax2o-WCw7uL-B3Tc_MoR3Lqq45L-9lWzEQHcpdxNksxhXlLDGVNMB5YAnRBtdIb5uZhwTWgMj88kxoMdic.M-5tV-8VpSuOx8Ky56x0fmmWhryHYp1rVxh109oWa-U&dib_tag=se&qid=1726930570&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-1113
# https://www.amazon.com/WIKO-Unlocked-Smartphone-Android-5000mAh/dp/B0C8984R5H
# https://www.amazon.com/Unlocked-Function-4800mAh-Battery-Flashlight/dp/B0CJ37YGJG/ref=sr_1_816?dib=eyJ2IjoiMSJ9.1vmFxzLouncrxABoyA4Usszvp9HYLNQRVKc7n-93MDdclbxwiPoR634UbuTTRUuClj5NTNirJzkHnv5CngYCcn9IrbI2phn7GLnovwku3NhxiZA-VhtyJFiLlYUemIyFHmlthTMMrlMx4Zp5vcnQpgG0elnSh_epbcPFvouALYJY8NhLJIJDPHsfzXd1V1Ij6mY3PiBj7hU__rmtMY-jITlvwgwzpjJ4mxRm1vRKMyfwchrhRf1cfRi9JIUOO7_peqaH3Agh2C0_oyzS_iPrHNSZnkYqBZttuuhmJb4Q548.UootFUrqmb9iTM5oRE7kRZh53ercZG2r7CMufFbdfmY&dib_tag=se&qid=1726930569&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-816
# https://www.amazon.com/DragoFab-Unlocked-Phones-Smartphone-Android/dp/B0D47VKRLK/ref=sr_1_3868?dib=eyJ2IjoiMSJ9.qSlFi9FE9Vt9OGIzzukCwMMVp533ppvXCa4WtnfTzKE4a8_aBA6yosEYpeKLTvuZTzw_9symiCzJ_rJXbHea6EfF_twEsKN7FJr0nKfGktXqrxEmBaQurZiNI0ARnD8PZwqWH93LFkzZgxob5zh_Wrw6MNxE6r91tm7--TBywx17uTOc7Dvx5aJtx7FvSAkqeE0_Rk5V4SLhw5JMFOAtkAbX4NIazpvjh95kjCPT8cKkDuI1_LXiU1E1yqqoS2MiQukpq0ZsprRmXmiwIK11JvfMlswuMfvewnF5kfEmyc0.tFCW4mxR4AQg9MyDEhI6XH-Tb7AN96F-7XXXwt6E9Zs&dib_tag=se&qid=1726930571&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-3868
#
# Data saved to amazon_product_data.csv

# %%
path = '/content/amazon_product_data.csv'
df = pd.read_csv(path)
df.head()
# Out:
#         color                                        image_links  \
# 0       Black  ['https://m.media-amazon.com/images/I/51E87drc...
# 1  Aura Black  ['https://m.media-amazon.com/images/I/41FroksW...
# 2       green  ['https://m.media-amazon.com/images/I/41KGmEhD...
# 3       Black  ['https://m.media-amazon.com/images/I/41xJFoKI...
# 4       Black  ['https://m.media-amazon.com/images/I/51mBltlO...
#
#                                         descriptions kind_product  ratings  \
# 0  CARRIER: This phone is locked to Tracfone, whi...  Cell Phones      4.1
# 1  Fully Unlocked: Fully unlocked and compatible ...  Cell Phones      4.2
# 2  FULL HD 6.26" SCREEN: The large 6.26" screen a...  Cell Phones      1.9
# 3                                                NaN  Cell Phones      4.2
# 4  【MTK Dimensity 7050+Android 13】Powered by the ...  Cell Phones      5.0
#
#   number_of_ratings    status number_of_buyers_last_month_more_than  \
# 0               465  In Stock                                   NaN
# 1             3,765       NaN                                  200+
# 2                 4       NaN                                   NaN
# 3                 9       NaN                                   50+
# 4                 2       NaN                                   NaN
#
#   typical_price price  ...   battery_power charging_time    ram storage  \
# 0       $119.99   72.  ...            3000           NaN   2 GB   32 GB
# 1       $314.00  189.  ...            3500    77 minutes  12 GB  256 GB
# 2        $79.95    49  ...             NaN           NaN    NaN    8 GB
# 3        $89.99   69.  ...             NaN           NaN   4 GB   64 GB
# 4           NaN  499.  ...  9600 Amp Hours           NaN  24 GB  512 GB
#
#    screen_size   connectivity_technologies wireless_network cpu_speed  \
# 0   5.5 Inches         Wireless, Bluetooth              NaN   1.4 GHz
# 1   6.3 Inches                   Bluetooth              NaN       NaN
# 2   6.3 Inches                  Wi-Fi, USB              NaN       NaN
# 3   6.5 Inches                    Wireless              NaN       NaN
# 4  6.58 Inches  Bluetooth, Wi-Fi, USB, NFC              NaN       NaN
#
#                                          reviews_usa  \
# 0                                                NaN
# 1  [{'name': 'ayalexander', 'rating': '5.0', 'cou...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        reviews_other
# 0                                                NaN
# 1  [{'name': 'Nayhely', 'rating': '5.0', 'country...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4499 entries, 0 to 4498
# Data columns (total 35 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   color                                  4238 non-null   object
#  1   image_links                            4464 non-null   object
#  2   descriptions                           3969 non-null   object
#  3   kind_product                           4497 non-null   object
#  4   ratings                                4166 non-null   float64
#  5   number_of_ratings                      4166 non-null   object
#  6   status                                 887 non-null    object
#  7   number_of_buyers_last_month_more_than  523 non-null    object
#  8   typical_price                          2839 non-null   object
#  9   price                                  4358 non-null   object
#  10  you_save                               0 non-null      float64
#  11  discount                               2839 non-null   object
#  12  brand                                  4414 non-null   object
#  13  os                                     4347 non-null   object
#  14  cpu_model                              781 non-null    object
#  15  resolution                             2758 non-null   object
#  16  name                                   4213 non-null   object
#  17  wireless_carrier                       4125 non-null   object
#  18  cellular_technology                    3700 non-null   object
#  19  dimensions                             4215 non-null   object
#  20  asin                                   4461 non-null   object
#  21  model                                  3459 non-null   object
#  22  amazon_renewed                         1304 non-null   float64
#  23  renewed_smartphones                    1304 non-null   float64
#  24  battery_capacity                       2653 non-null   object
#  25  battery_power                          2414 non-null   object
#  26  charging_time                          629 non-null    object
#  27  ram                                    3409 non-null   object
#  28  storage                                4326 non-null   object
#  29  screen_size                            4173 non-null   object
#  30  connectivity_technologies              3934 non-null   object
#  31  wireless_network                       706 non-null    object
#  32  cpu_speed                              1731 non-null   object
#  33  reviews_usa                            1196 non-null   object
#  34  reviews_other                          464 non-null    object
# dtypes: float64(4), object(31)
# memory usage: 1.2+ MB

# %%
df['typical_price'] = df['typical_price'].replace({'\$': '', ',': ''}, regex=True).astype(float)
df['number_of_buyers_last_month_more_than'] = df['number_of_buyers_last_month_more_than'].replace({'K': '000', '\+': ''}, regex=True).astype(float)
df['number_of_ratings']= df['number_of_ratings'].replace({ '\,': ''}, regex=True).astype(float)
df['price'] = df['price'].replace({'\$': '', ',': ''}, regex=True).astype(float)

df['you_save'] = df['typical_price'] - df['price']

df.to_csv(path, index=False)

df.dtypes
# Out:
# color                                     object
# image_links                               object
# descriptions                              object
# kind_product                              object
# ratings                                  float64
# number_of_ratings                        float64
# status                                    object
# number_of_buyers_last_month_more_than    float64
# typical_price                            float64
# price                                    float64
# you_save                                 float64
# discount                                  object
# brand                                     object
# os                                        object
# cpu_model                                 object
# resolution                                object
# name                                      object
# wireless_carrier                          object
# cellular_technology                       object
# dimensions                                object
# asin                                      object
# model                                     object
# amazon_renewed                           float64
# renewed_smartphones                      float64
# battery_capacity                          object
# battery_power                             object
# charging_time                             object
# ram                                       object
# storage                                   object
# screen_size                               object
# connectivity_technologies                 object
# wireless_network                          object
# cpu_speed                                 object
# reviews_usa                               object
# reviews_other                             object
# dtype: object

# %%
df.head()
# Out:
#         color                                        image_links  \
# 0       Black  ['https://m.media-amazon.com/images/I/51E87drc...
# 1  Aura Black  ['https://m.media-amazon.com/images/I/41FroksW...
# 2       green  ['https://m.media-amazon.com/images/I/41KGmEhD...
# 3       Black  ['https://m.media-amazon.com/images/I/41xJFoKI...
# 4       Black  ['https://m.media-amazon.com/images/I/51mBltlO...
#
#                                         descriptions kind_product  ratings  \
# 0  CARRIER: This phone is locked to Tracfone, whi...  Cell Phones      4.1
# 1  Fully Unlocked: Fully unlocked and compatible ...  Cell Phones      4.2
# 2  FULL HD 6.26" SCREEN: The large 6.26" screen a...  Cell Phones      1.9
# 3                                                NaN  Cell Phones      4.2
# 4  【MTK Dimensity 7050+Android 13】Powered by the ...  Cell Phones      5.0
#
#    number_of_ratings    status  number_of_buyers_last_month_more_than  \
# 0              465.0  In Stock                                    NaN
# 1             3765.0       NaN                                  200.0
# 2                4.0       NaN                                    NaN
# 3                9.0       NaN                                   50.0
# 4                2.0       NaN                                    NaN
#
#    typical_price  price  ...   battery_power charging_time    ram storage  \
# 0         119.99   72.0  ...            3000           NaN   2 GB   32 GB
# 1         314.00  189.0  ...            3500    77 minutes  12 GB  256 GB
# 2          79.95   49.0  ...             NaN           NaN    NaN    8 GB
# 3          89.99   69.0  ...             NaN           NaN   4 GB   64 GB
# 4            NaN  499.0  ...  9600 Amp Hours           NaN  24 GB  512 GB
#
#    screen_size   connectivity_technologies wireless_network cpu_speed  \
# 0   5.5 Inches         Wireless, Bluetooth              NaN   1.4 GHz
# 1   6.3 Inches                   Bluetooth              NaN       NaN
# 2   6.3 Inches                  Wi-Fi, USB              NaN       NaN
# 3   6.5 Inches                    Wireless              NaN       NaN
# 4  6.58 Inches  Bluetooth, Wi-Fi, USB, NFC              NaN       NaN
#
#                                          reviews_usa  \
# 0                                                NaN
# 1  [{'name': 'ayalexander', 'rating': '5.0', 'cou...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        reviews_other
# 0                                                NaN
# 1  [{'name': 'Nayhely', 'rating': '5.0', 'country...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4499 entries, 0 to 4498
# Data columns (total 35 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   color                                  4238 non-null   object
#  1   image_links                            4464 non-null   object
#  2   descriptions                           3969 non-null   object
#  3   kind_product                           4497 non-null   object
#  4   ratings                                4166 non-null   float64
#  5   number_of_ratings                      4166 non-null   float64
#  6   status                                 887 non-null    object
#  7   number_of_buyers_last_month_more_than  523 non-null    float64
#  8   typical_price                          2839 non-null   float64
#  9   price                                  4358 non-null   float64
#  10  you_save                               2838 non-null   float64
#  11  discount                               2839 non-null   object
#  12  brand                                  4414 non-null   object
#  13  os                                     4347 non-null   object
#  14  cpu_model                              781 non-null    object
#  15  resolution                             2758 non-null   object
#  16  name                                   4213 non-null   object
#  17  wireless_carrier                       4125 non-null   object
#  18  cellular_technology                    3700 non-null   object
#  19  dimensions                             4215 non-null   object
#  20  asin                                   4461 non-null   object
#  21  model                                  3459 non-null   object
#  22  amazon_renewed                         1304 non-null   float64
#  23  renewed_smartphones                    1304 non-null   float64
#  24  battery_capacity                       2653 non-null   object
#  25  battery_power                          2414 non-null   object
#  26  charging_time                          629 non-null    object
#  27  ram                                    3409 non-null   object
#  28  storage                                4326 non-null   object
#  29  screen_size                            4173 non-null   object
#  30  connectivity_technologies              3934 non-null   object
#  31  wireless_network                       706 non-null    object
#  32  cpu_speed                              1731 non-null   object
#  33  reviews_usa                            1196 non-null   object
#  34  reviews_other                          464 non-null    object
# dtypes: float64(8), object(27)
# memory usage: 1.2+ MB

# %%
# test links
links= ['https://www.amazon.com/Electronics-Unlocked-Smartphone-Pro-Grade-SM-G998UZKAXAA/dp/B08VL1Q7Z1/ref=pd_ci_mcx_di_int_sccai_cn_d_sccl_2_3/137-9844677-7401249?pd_rd_w=tlFXA&content-id=amzn1.sym.751acc83-5c05-42d0-a15e-303622651e1e&pf_rd_p=751acc83-5c05-42d0-a15e-303622651e1e&pf_rd_r=8VXBDV9S4ZWEVMM5J7WF&pd_rd_wg=tD3bN&pd_rd_r=2648defa-97bd-4581-9454-2e89bfe9d28b&pd_rd_i=B08VL1Q7Z1&psc=1',
'https://www.amazon.com/Samsung-Electronics-Unlocked-Smartphone-Long-Lasting/dp/B08BX7N9SK/ref=pd_ci_mcx_di_int_sccai_cn_d_sccl_3_3/137-9844677-7401249?pd_rd_w=Ncv02&content-id=amzn1.sym.751acc83-5c05-42d0-a15e-303622651e1e&pf_rd_p=751acc83-5c05-42d0-a15e-303622651e1e&pf_rd_r=PCZ7W22Q2HAT4KVCCTQ2&pd_rd_wg=uKLAT&pd_rd_r=6b1d67c6-44c7-4573-a7ee-88a86666a091&pd_rd_i=B08BX7XBGN&th=1',
'https://www.amazon.com/Samsung-Electronics-Unlocked-Smartphone-Long-Lasting/dp/B08HKRVZ4W/ref=pd_ci_mcx_di_int_sccai_cn_d_sccl_2_10/137-9844677-7401249?pd_rd_w=6NwkB&content-id=amzn1.sym.751acc83-5c05-42d0-a15e-303622651e1e&pf_rd_p=751acc83-5c05-42d0-a15e-303622651e1e&pf_rd_r=3P2S1RZFT25DWJM34AK5&pd_rd_wg=Iyqyd&pd_rd_r=62471bad-df94-4e6d-970a-3e597876d3a8&pd_rd_i=B08HQZC2XK&th=1',
'https://www.amazon.com/Nokia-9500-Unlocked-Smartphone-MMC-U-S/dp/B0009VB0NG/ref=sr_1_4521?dib=eyJ2IjoiMSJ9.XJtBUAuXwJ71WsS74wvDTi0Dc0u7LFg4l94ZnQ35n_AeEjgaU4ImnEA2DeHmZqJlXciEJxwPAk4z5eHEG6TbptTrSrBz3xlCQa4tgAC1C5JP-VeV6RjuUjpfX_2-QrJMbnMBELXRLARPHDvAoF5ryw.v-ZdedqI3EN6oSZo7HaD3hT88NKQeg6IR2Zo7u7vwRM&dib_tag=se&qid=1726754973&refinements=p_n_feature_thirty-nine_browse-bin%3A113334727011%7C113334728011%7C113334729011%7C113334730011%7C113334731011%7C113334732011&rnid=113334702011&s=wireless&sr=1-4521']
